# %%
# Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
names=["Allied Signal","Bankers Trust","General Mills","ITT Industries","J.P.Morgan & Co.","LehmanBrothers","Marrio","MCI","Merrill Lynch","Microso","Morgan Stanley","SunMicrosystems","Travelers","US Airways","Warner-Lambert"]
# %matplotlib inline
fig=plt.figure(figsize=(8,8))
plt.pie(data,labels=names,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\kiran\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 57344 (\ue000) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kiran\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 57345 (\ue001) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15 entries, 0 to 14
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 15 non-null     float64
# dtypes: float64(1)
# memory usage: 252.0 bytes

# %%
data.describe()
# Out:
# count    15.000000
# mean     33.271333
# std      16.945401
# min      24.140000
# 25%      25.470000
# 50%      26.710000
# 75%      33.975000
# max      91.360000
# dtype: float64

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.mean()
# Out:
# 33.27133333333333

# %%
data.var()
# Out:
# 287.1466123809524

# %%
data.std()
# Out:
# 16.945400921222028

# %%
df1 = pd.DataFrame({"x":[-2000,-1000,0,1000,2000,3000],"P(x)":[0.1,0.1,0.2,0.2,0.3,0.1]})

# %%
df1_probability = df1['x']*df1["P(x)"]

# %%
df1_probability
# Out:
# 0   -200.0
# 1   -100.0
# 2      0.0
# 3    200.0
# 4    600.0
# 5    300.0
# dtype: float64

# %%
df1_probability.mean()
# Out:
# 133.33333333333334

# %%
df1_probability.std()
# Out:
# 294.3920288775949

# %%
df1_probability.var()
# Out:
# 86666.66666666666
